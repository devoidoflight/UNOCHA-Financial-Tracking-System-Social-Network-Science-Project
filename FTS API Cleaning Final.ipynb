# %%
import os
import pandas as pd
import ast
# Specify the directory containing the Excel files
directory = 'C:/Users/boran/Desktop/Network/FTS Project/Son/Ülke Verileri/Ülke Verileri/'

# %%
# Tüm ülkelerin verilerini birleştiriyor. 
# Create an empty DataFrame to store aggregated data
aggregated_df = pd.DataFrame()

# Function to extract the appropriate word from the filename
def extract_word_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove the file extension

    # Find the last word (from last letter to first space)
    last_word = base_name.split()[-1]
    
    # Check if the last word is "None" and then extract the first word before the first underscore
    if last_word.lower() == 'none':
        first_word = base_name.split('_')[0]
        return first_word
    else:
        return last_word

# Loop through the files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".xlsx"):  # Check if the file is an Excel file
        file_path = os.path.join(directory, filename)  # Construct full file path
        df = pd.read_excel(file_path)  # Load the file as a DataFrame

        # Extract the appropriate word from the filename
        extracted_word = extract_word_from_filename(filename)

        # Add a new column to the DataFrame
        df['SourceWord'] = extracted_word

        # Print the file name and the first few rows of its DataFrame
        print(f"Processing file: {filename}, Adding SourceWord: {extracted_word}")

        # Concatenate the current file's DataFrame to the aggregated DataFrame
        aggregated_df = pd.concat([aggregated_df, df], ignore_index=True)

# After looping through all files, you can work with the aggregated DataFrame
print("Aggregated DataFrame:")
print(aggregated_df.head())
# Out:
# Processing file: Afghanistan_ AFG.xlsx, Adding SourceWord: AFG
# Processing file: Albania_ ALB.xlsx, Adding SourceWord: ALB
# Processing file: Algeria_ DZA.xlsx, Adding SourceWord: DZA
# Processing file: American Samoa_ ASM.xlsx, Adding SourceWord: ASM
# Processing file: Angola_ AGO.xlsx, Adding SourceWord: AGO
# Processing file: Anguilla (United Kingdom)_ None.xlsx, Adding SourceWord: Anguilla (United Kingdom)
# Processing file: Antigua and Barbuda_ ATG.xlsx, Adding SourceWord: ATG
# Processing file: Argentina_ ARG.xlsx, Adding SourceWord: ARG
# Processing file: Armenia_ ARM.xlsx, Adding SourceWord: ARM
# Processing file: Aruba_ ABW.xlsx, Adding SourceWord: ABW
# Processing file: Australia_ AUS.xlsx, Adding SourceWord: AUS
# Processing file: Austria_ AUT.xlsx, Adding SourceWord: AUT
# Processing file: Azerbaijan_ AZE.xlsx, Adding SourceWord: AZE
# Processing file: Bahamas_ BHS.xlsx, Adding SourceWord: BHS
# Processing file: Bangladesh_ BGD.xlsx, Adding SourceWord: BGD
# Processing file: Barbados_ BRB.xlsx, Adding SourceWord: BRB
# Processing file: Belarus_ BLR.xlsx, Adding SourceWord: BLR
# Processing file: Belgium_ BEL.xlsx, Adding SourceWord: BEL
# Processing file: Belize_ BLZ.xlsx, Adding SourceWord: BLZ
# Processing file: Benin_ BEN.xlsx, Adding SourceWord: BEN
# Processing file: Bhutan_ BTN.xlsx, Adding SourceWord: BTN
# Processing file: Bolivia, Plurinational State…_ None.xlsx, Adding SourceWord: Bolivia, Plurinational State…
# Processing file: Bonaire, Saint Eustatius and…_ None.xlsx, Adding SourceWord: Bonaire, Saint Eustatius and…
# Processing file: Bosnia and Herzegovina_ BIH.xlsx, Adding SourceWord: BIH
# Processing file: Botswana_ BWA.xlsx, Adding SourceWord: BWA
# Processing file: Brazil_ BRA.xlsx, Adding SourceWord: BRA
# Processing file: Brunei Darussalam_ BRN.xlsx, Adding SourceWord: BRN
# Processing file: Bulgaria_ BGR.xlsx, Adding SourceWord: BGR
# Processing file: Burkina Faso_ BFA.xlsx, Adding SourceWord: BFA
# Processing file: Burundi_ BDI.xlsx, Adding SourceWord: BDI
# Processing file: Cambodia_ KHM.xlsx, Adding SourceWord: KHM
# Processing file: Cameroon_ CMR.xlsx, Adding SourceWord: CMR
# Processing file: Canada_ CAN.xlsx, Adding SourceWord: CAN
# Processing file: Cape Verde_ None.xlsx, Adding SourceWord: Cape Verde
# Processing file: Cayman Islands_ CYM.xlsx, Adding SourceWord: CYM
# Processing file: Central African Republic_ CAF.xlsx, Adding SourceWord: CAF
# Processing file: Chad_ TCD.xlsx, Adding SourceWord: TCD
# Processing file: Chile_ CHL.xlsx, Adding SourceWord: CHL
# Processing file: China_ CHN.xlsx, Adding SourceWord: CHN
# Processing file: Colombia_ COL.xlsx, Adding SourceWord: COL
# Processing file: Comoros_ COM.xlsx, Adding SourceWord: COM
# Processing file: Congo, The Democratic…_ None.xlsx, Adding SourceWord: Congo, The Democratic…
# Processing file: Congo_ COG.xlsx, Adding SourceWord: COG
# Processing file: Cook Islands_ COK.xlsx, Adding SourceWord: COK
# Processing file: Costa Rica_ CRI.xlsx, Adding SourceWord: CRI
# Processing file: Croatia_ HRV.xlsx, Adding SourceWord: HRV
# Processing file: Cuba_ CUB.xlsx, Adding SourceWord: CUB
# Processing file: Curaçao_ CUW.xlsx, Adding SourceWord: CUW
# Processing file: Cyprus_ CYP.xlsx, Adding SourceWord: CYP
# Processing file: Czech Republic_ CZE.xlsx, Adding SourceWord: CZE
# Processing file: Côte d_Ivoire_ CIV.xlsx, Adding SourceWord: CIV
# Processing file: Denmark_ DNK.xlsx, Adding SourceWord: DNK
# Processing file: Djibouti_ DJI.xlsx, Adding SourceWord: DJI
# Processing file: Dominican Republic_ DOM.xlsx, Adding SourceWord: DOM
# Processing file: Dominica_ DMA.xlsx, Adding SourceWord: DMA
# Processing file: Ecuador_ ECU.xlsx, Adding SourceWord: ECU
# Processing file: Egypt_ EGY.xlsx, Adding SourceWord: EGY
# Processing file: El Salvador_ SLV.xlsx, Adding SourceWord: SLV
# Processing file: Equatorial Guinea_ GNQ.xlsx, Adding SourceWord: GNQ
# Processing file: Eritrea_ ERI.xlsx, Adding SourceWord: ERI
# Processing file: Estonia_ EST.xlsx, Adding SourceWord: EST
# Processing file: Eswatini_ SWZ.xlsx, Adding SourceWord: SWZ
# Processing file: Ethiopia_ ETH.xlsx, Adding SourceWord: ETH
# Processing file: Falkland Islands (Malvinas)_ FLK.xlsx, Adding SourceWord: FLK
# Processing file: Fiji_ FJI.xlsx, Adding SourceWord: FJI
# Processing file: France_ FRA.xlsx, Adding SourceWord: FRA
# Processing file: French Polynesia_ PYF.xlsx, Adding SourceWord: PYF
# Processing file: Gabon_ GAB.xlsx, Adding SourceWord: GAB
# Processing file: Gambia_ GMB.xlsx, Adding SourceWord: GMB
# Processing file: Georgia_ GEO.xlsx, Adding SourceWord: GEO
# Processing file: Germany_ DEU.xlsx, Adding SourceWord: DEU
# Processing file: Ghana_ GHA.xlsx, Adding SourceWord: GHA
# Processing file: Global_ None.xlsx, Adding SourceWord: Global
# Processing file: Greece_ GRC.xlsx, Adding SourceWord: GRC
# Processing file: Grenada_ GRD.xlsx, Adding SourceWord: GRD
# Processing file: Guadeloupe (France)_ None.xlsx, Adding SourceWord: Guadeloupe (France)
# Processing file: Guam_ GUM.xlsx, Adding SourceWord: GUM
# Processing file: Guatemala_ GTM.xlsx, Adding SourceWord: GTM
# Processing file: Guinea-Bissau_ GNB.xlsx, Adding SourceWord: GNB
# Processing file: Guinea_ GIN.xlsx, Adding SourceWord: GIN
# Processing file: Guyana_ GUY.xlsx, Adding SourceWord: GUY
# Processing file: Haiti_ HTI.xlsx, Adding SourceWord: HTI
# Processing file: Honduras_ HND.xlsx, Adding SourceWord: HND
# Processing file: Hungary_ HUN.xlsx, Adding SourceWord: HUN
# Processing file: Iceland_ ISL.xlsx, Adding SourceWord: ISL
# Processing file: India_ IND.xlsx, Adding SourceWord: IND
# Processing file: Indonesia_ IDN.xlsx, Adding SourceWord: IDN
# Processing file: Iran_ IRN.xlsx, Adding SourceWord: IRN
# Processing file: Iraq_ IRQ.xlsx, Adding SourceWord: IRQ
# Processing file: Ireland_ IRL.xlsx, Adding SourceWord: IRL
# Processing file: Israel_ ISR.xlsx, Adding SourceWord: ISR
# Processing file: Italy_ ITA.xlsx, Adding SourceWord: ITA
# Processing file: Jamaica_ JAM.xlsx, Adding SourceWord: JAM
# Processing file: Japan_ JPN.xlsx, Adding SourceWord: JPN
# Processing file: Jordan_ JOR.xlsx, Adding SourceWord: JOR
# Processing file: Kazakhstan_ KAZ.xlsx, Adding SourceWord: KAZ
# Processing file: Kenya_ KEN.xlsx, Adding SourceWord: KEN
# Processing file: Kiribati_ KIR.xlsx, Adding SourceWord: KIR
# Processing file: Korea, Democratic People_s…_ None.xlsx, Adding SourceWord: Korea, Democratic People
# Processing file: Korea, Republic of_ KOR.xlsx, Adding SourceWord: KOR
# Processing file: Kuwait_ KWT.xlsx, Adding SourceWord: KWT
# Processing file: Kyrgyzstan_ KGZ.xlsx, Adding SourceWord: KGZ
# Processing file: Lao People_s Democratic…_ None.xlsx, Adding SourceWord: Lao People
# Processing file: Latvia_ LVA.xlsx, Adding SourceWord: LVA
# Processing file: Lebanon_ LBN.xlsx, Adding SourceWord: LBN
# Processing file: Lesotho_ LSO.xlsx, Adding SourceWord: LSO
# Processing file: Liberia_ LBR.xlsx, Adding SourceWord: LBR
# Processing file: Libya_ LBY.xlsx, Adding SourceWord: LBY
# Processing file: Lithuania_ LTU.xlsx, Adding SourceWord: LTU
# Processing file: Luxembourg_ LUX.xlsx, Adding SourceWord: LUX
# Processing file: Madagascar_ MDG.xlsx, Adding SourceWord: MDG
# Processing file: Malawi_ MWI.xlsx, Adding SourceWord: MWI
# Processing file: Malaysia_ MYS.xlsx, Adding SourceWord: MYS
# Processing file: Maldives_ MDV.xlsx, Adding SourceWord: MDV
# Processing file: Mali_ MLI.xlsx, Adding SourceWord: MLI
# Processing file: Malta_ MLT.xlsx, Adding SourceWord: MLT
# Processing file: Marshall Islands_ MHL.xlsx, Adding SourceWord: MHL
# Processing file: Martinique (France)_ None.xlsx, Adding SourceWord: Martinique (France)
# Processing file: Mauritania_ MRT.xlsx, Adding SourceWord: MRT
# Processing file: Mauritius_ MUS.xlsx, Adding SourceWord: MUS
# Processing file: Mexico_ MEX.xlsx, Adding SourceWord: MEX
# Processing file: Micronesia, Federated States…_ None.xlsx, Adding SourceWord: Micronesia, Federated States…
# Processing file: Moldova, Republic of_ MDA.xlsx, Adding SourceWord: MDA
# Processing file: Mongolia_ MNG.xlsx, Adding SourceWord: MNG
# Processing file: Montenegro_ MNE.xlsx, Adding SourceWord: MNE
# Processing file: Montserrat_ MSR.xlsx, Adding SourceWord: MSR
# Processing file: Morocco_ MAR.xlsx, Adding SourceWord: MAR
# Processing file: Mozambique_ MOZ.xlsx, Adding SourceWord: MOZ
# Processing file: Myanmar_ MMR.xlsx, Adding SourceWord: MMR
# Processing file: Namibia_ NAM.xlsx, Adding SourceWord: NAM
# Processing file: Nauru_ NRU.xlsx, Adding SourceWord: NRU
# Processing file: Nepal_ NPL.xlsx, Adding SourceWord: NPL
# Processing file: Netherlands_ NLD.xlsx, Adding SourceWord: NLD
# Processing file: New Caledonia_ NCL.xlsx, Adding SourceWord: NCL
# Processing file: New Zealand_ NZL.xlsx, Adding SourceWord: NZL
# Processing file: Nicaragua_ NIC.xlsx, Adding SourceWord: NIC
# Processing file: Nigeria_ NGA.xlsx, Adding SourceWord: NGA
# Processing file: Niger_ NER.xlsx, Adding SourceWord: NER
# Processing file: Niue_ NIU.xlsx, Adding SourceWord: NIU
# Processing file: North Macedonia_ MKD.xlsx, Adding SourceWord: MKD
# Processing file: Norway_ NOR.xlsx, Adding SourceWord: NOR
# Processing file: occupied Palestinian territory_ None.xlsx, Adding SourceWord: occupied Palestinian territory
# Processing file: Oman_ OMN.xlsx, Adding SourceWord: OMN
# Processing file: Pakistan_ PAK.xlsx, Adding SourceWord: PAK
# Processing file: Palau_ PLW.xlsx, Adding SourceWord: PLW
# Processing file: Panama_ PAN.xlsx, Adding SourceWord: PAN
# Processing file: Papua New Guinea_ PNG.xlsx, Adding SourceWord: PNG
# Processing file: Paraguay_ PRY.xlsx, Adding SourceWord: PRY
# Processing file: Peru_ PER.xlsx, Adding SourceWord: PER
# Processing file: Philippines_ PHL.xlsx, Adding SourceWord: PHL
# Processing file: Poland_ POL.xlsx, Adding SourceWord: POL
# Processing file: Portugal_ PRT.xlsx, Adding SourceWord: PRT
# Processing file: Puerto Rico (United States)_ None.xlsx, Adding SourceWord: Puerto Rico (United States)
# Processing file: Qatar_ QAT.xlsx, Adding SourceWord: QAT
# Processing file: Romania_ ROU.xlsx, Adding SourceWord: ROU
# Processing file: Russian Federation_ RUS.xlsx, Adding SourceWord: RUS
# Processing file: Rwanda_ RWA.xlsx, Adding SourceWord: RWA
# Processing file: Saint Barthélemy (France)_ None.xlsx, Adding SourceWord: Saint Barthélemy (France)
# Processing file: Saint Helena, Ascension and…_ None.xlsx, Adding SourceWord: Saint Helena, Ascension and…
# Processing file: Saint Kitts and Nevis_ KNA.xlsx, Adding SourceWord: KNA
# Processing file: Saint Lucia_ LCA.xlsx, Adding SourceWord: LCA
# Processing file: Saint Martin (France)_ None.xlsx, Adding SourceWord: Saint Martin (France)
# Processing file: Saint Vincent and the…_ None.xlsx, Adding SourceWord: Saint Vincent and the…
# Processing file: Samoa_ WSM.xlsx, Adding SourceWord: WSM
# Processing file: San Marino_ SMR.xlsx, Adding SourceWord: SMR
# Processing file: Saudi Arabia_ SAU.xlsx, Adding SourceWord: SAU
# Processing file: Senegal_ SEN.xlsx, Adding SourceWord: SEN
# Processing file: Serbia and Montenegro _ None.xlsx, Adding SourceWord: Serbia and Montenegro
# Processing file: Serbia_ SRB.xlsx, Adding SourceWord: SRB
# Processing file: Seychelles_ SYC.xlsx, Adding SourceWord: SYC
# Processing file: Sierra Leone_ SLE.xlsx, Adding SourceWord: SLE
# Processing file: Singapore_ SGP.xlsx, Adding SourceWord: SGP
# Processing file: Sint Maarten (Dutch part)_ SXM.xlsx, Adding SourceWord: SXM
# Processing file: Slovakia_ SVK.xlsx, Adding SourceWord: SVK
# Processing file: Slovenia_ SVN.xlsx, Adding SourceWord: SVN
# Processing file: Solomon Islands_ SLB.xlsx, Adding SourceWord: SLB
# Processing file: Somalia_ SOM.xlsx, Adding SourceWord: SOM
# Processing file: South Africa_ ZAF.xlsx, Adding SourceWord: ZAF
# Processing file: South Sudan_ SSD.xlsx, Adding SourceWord: SSD
# Processing file: Spain_ ESP.xlsx, Adding SourceWord: ESP
# Processing file: Sri Lanka_ LKA.xlsx, Adding SourceWord: LKA
# Processing file: Sudan_ SDN.xlsx, Adding SourceWord: SDN
# Processing file: Suriname_ SUR.xlsx, Adding SourceWord: SUR
# Processing file: Sweden_ SWE.xlsx, Adding SourceWord: SWE
# Processing file: Switzerland_ CHE.xlsx, Adding SourceWord: CHE
# Processing file: Syrian Arab Republic_ SYR.xlsx, Adding SourceWord: SYR
# Processing file: SÃ£o TomÃ© and PrÃ­ncipe_ None.xlsx, Adding SourceWord: SÃ£o TomÃ© and PrÃ­ncipe
# Processing file: Taiwan, Province of China_ TWN.xlsx, Adding SourceWord: TWN
# Processing file: Tajikistan_ TJK.xlsx, Adding SourceWord: TJK
# Processing file: Tanzania_ TZA.xlsx, Adding SourceWord: TZA
# Processing file: Thailand_ THA.xlsx, Adding SourceWord: THA
# Processing file: Timor-Leste_ TLS.xlsx, Adding SourceWord: TLS
# Processing file: Togo_ TGO.xlsx, Adding SourceWord: TGO
# Processing file: Tokelau_ TKL.xlsx, Adding SourceWord: TKL
# Processing file: Tonga_ TON.xlsx, Adding SourceWord: TON
# Processing file: Trinidad and Tobago_ TTO.xlsx, Adding SourceWord: TTO
# Processing file: Tunisia_ TUN.xlsx, Adding SourceWord: TUN
# Processing file: Turkmenistan_ TKM.xlsx, Adding SourceWord: TKM
# Processing file: Turks and Caicos Islands_ TCA.xlsx, Adding SourceWord: TCA
# Processing file: Tuvalu_ TUV.xlsx, Adding SourceWord: TUV
# Processing file: TÃ¼rkiye_ TUR.xlsx, Adding SourceWord: TUR
# Processing file: Uganda_ UGA.xlsx, Adding SourceWord: UGA
# Processing file: Ukraine_ UKR.xlsx, Adding SourceWord: UKR
# Processing file: United Arab Emirates_ ARE.xlsx, Adding SourceWord: ARE
# Processing file: United Kingdom_ GBR.xlsx, Adding SourceWord: GBR
# Processing file: United States_ USA.xlsx, Adding SourceWord: USA
# Processing file: Uruguay_ URY.xlsx, Adding SourceWord: URY
# Processing file: Uzbekistan_ UZB.xlsx, Adding SourceWord: UZB
# Processing file: Vanuatu_ VUT.xlsx, Adding SourceWord: VUT
# Processing file: Vatican_ None.xlsx, Adding SourceWord: Vatican
# Processing file: Venezuela, Bolivarianâ€¦_ None.xlsx, Adding SourceWord: Venezuela, Bolivarianâ€¦
# Processing file: Viet Nam_ VNM.xlsx, Adding SourceWord: VNM
# Processing file: Virgin Islands, British_ VGB.xlsx, Adding SourceWord: VGB
# Processing file: Western Sahara_ ESH.xlsx, Adding SourceWord: ESH
# Processing file: Yemen_ YEM.xlsx, Adding SourceWord: YEM
# Processing file: Zambia_ ZMB.xlsx, Adding SourceWord: ZMB
# Processing file: Zimbabwe_ ZWE.xlsx, Adding SourceWord: ZWE
# Aggregated DataFrame:
#    Unnamed: 0        id  amountUSD  budgetYear childFlowIds contributionType  \
# 0         0.0  100131.0   621891.0      2013.0          NaN        financial
# 1         1.0  100144.0    90928.0      2012.0          NaN        financial
# 2         2.0  100145.0    47680.0      2012.0          NaN        financial
# 3         3.0  100146.0  1358086.0      2012.0          NaN        financial
# 4         4.0  100147.0   117952.0      2012.0          NaN        financial
#
#               createdAt                  date          decisionDate  \
# 0  2012-11-12T16:26:00Z  2012-07-10T00:00:00Z  2012-07-10T00:00:00Z
# 1  2012-11-13T10:33:00Z  2012-05-01T00:00:00Z  2012-05-01T00:00:00Z
# 2  2012-11-13T10:37:00Z  2012-05-01T00:00:00Z  2012-05-01T00:00:00Z
# 3  2012-11-13T10:43:00Z  2012-09-01T00:00:00Z  2012-09-01T00:00:00Z
# 4  2012-11-13T10:44:00Z  2012-09-01T00:00:00Z  2012-09-01T00:00:00Z
#
#                                          description  ...      status  \
# 0  Multilateral contribution to UNMAS: Support to...  ...  commitment
# 1  Emergency WASH support to schools in drought i...  ...        paid
# 2  Emergency Support to Drought and floods affect...  ...        paid
# 3  Kandahar and Jawzjan Integrated and Sustainabl...  ...        paid
# 4  Kandahar and Jawzjan Integrated and Sustainabl...  ...        paid
#
#               updatedAt versionId  \
# 0  2013-06-17T13:54:00Z       1.0
# 1  2012-11-13T10:33:00Z       1.0
# 2  2012-11-13T10:37:00Z       1.0
# 3  2012-11-13T10:43:00Z       1.0
# 4  2012-11-13T10:44:00Z       1.0
#
#                                        sourceObjects  \
# 0  [{'type': 'Organization', 'id': '3774', 'name'...
# 1  [{'type': 'Organization', 'id': '2917', 'name'...
# 2  [{'type': 'Organization', 'id': '2917', 'name'...
# 3  [{'type': 'Organization', 'id': '2933', 'name'...
# 4  [{'type': 'Organization', 'id': '2933', 'name'...
#
#                                   destinationObjects  boundary  onBoundary  \
# 0  [{'type': 'Plan', 'id': '399', 'name': 'Afghan...  incoming      single
# 1  [{'type': 'Plan', 'id': '370', 'name': 'Afghan...  incoming      single
# 2  [{'type': 'Plan', 'id': '370', 'name': 'Afghan...  incoming      single
# 3  [{'type': 'Plan', 'id': '370', 'name': 'Afghan...  incoming      single
# 4  [{'type': 'Plan', 'id': '370', 'name': 'Afghan...  incoming      single
#
#                                        reportDetails        refCode  \
# 0  [{'sourceType': 'Primary', 'organization': 'It...  AID 9908/01/0
# 1  [{'sourceType': 'Primary', 'organization': 'Te...            NaN
# 2  [{'sourceType': 'Primary', 'organization': 'Te...            NaN
# 3  [{'sourceType': 'Primary', 'organization': 'Te...            NaN
# 4  [{'sourceType': 'Primary', 'organization': 'Te...            NaN
#
#    SourceWord
# 0         AFG
# 1         AFG
# 2         AFG
# 3         AFG
# 4         AFG
#
# [5 rows x 30 columns]

# %%
# str halde olan sütunu list of dicts'e çeviriyorum
def parse_str_to_list(string):
    try:
        return ast.literal_eval(string)
    except (ValueError, SyntaxError):
        return None

# Apply the function to the DataFrame column
aggregated_df['sourceObjects'] = aggregated_df['sourceObjects'].apply(parse_str_to_list)

# %%
# Kaç tane organizasyondan bahsedildiğini sayıyorum ve yeni kolon olarak ekliyorum
def count_organization_types(obj_list):
    return sum(1 for obj in obj_list if obj.get('type') == 'Organization')

# Apply the function to each row and add the count as a new column
aggregated_df['Organization Count'] = aggregated_df['sourceObjects'].apply(count_organization_types)

# %%
# Dictlerden organizasyonların infolarını çekiyorum.
def extract_organization_info_conditional(dicts, count):
    if count != 1:
        return {'Organization': '', 'Organization Type': '', 'Organization Sub Type': '', 'Organization Level': ''}
    for d in dicts:
        if d['type'] == 'Organization':
            return {
                'Organization': d.get('name', ''),
                'Organization Type': ', '.join(d.get('organizationTypes', [])),
                'Organization Sub Type': ', '.join(d.get('organizationSubTypes', [])),
                'Organization Level': ', '.join(d.get('organizationLevels', []))
            }
    return {'Organization': '', 'Organization Type': '', 'Organization Sub Type': '', 'Organization Level': ''}

# Apply the function conditionally based on 'Organization Count'
aggregated_df[['Organization', 'Organization Type', 'Organization Sub Type', 'Organization Level']] = aggregated_df.apply(
    lambda row: pd.Series(extract_organization_info_conditional(row['sourceObjects'], row['Organization Count'])),
    axis=1
)

# %%
aggregated_df.head()
# Out:
#    Unnamed: 0        id  amountUSD  budgetYear childFlowIds contributionType  \
# 0         0.0  100131.0   621891.0      2013.0          NaN        financial
# 1         1.0  100144.0    90928.0      2012.0          NaN        financial
# 2         2.0  100145.0    47680.0      2012.0          NaN        financial
# 3         3.0  100146.0  1358086.0      2012.0          NaN        financial
# 4         4.0  100147.0   117952.0      2012.0          NaN        financial
#
#               createdAt                  date          decisionDate  \
# 0  2012-11-12T16:26:00Z  2012-07-10T00:00:00Z  2012-07-10T00:00:00Z
# 1  2012-11-13T10:33:00Z  2012-05-01T00:00:00Z  2012-05-01T00:00:00Z
# 2  2012-11-13T10:37:00Z  2012-05-01T00:00:00Z  2012-05-01T00:00:00Z
# 3  2012-11-13T10:43:00Z  2012-09-01T00:00:00Z  2012-09-01T00:00:00Z
# 4  2012-11-13T10:44:00Z  2012-09-01T00:00:00Z  2012-09-01T00:00:00Z
#
#                                          description  ...  boundary  \
# 0  Multilateral contribution to UNMAS: Support to...  ...  incoming
# 1  Emergency WASH support to schools in drought i...  ...  incoming
# 2  Emergency Support to Drought and floods affect...  ...  incoming
# 3  Kandahar and Jawzjan Integrated and Sustainabl...  ...  incoming
# 4  Kandahar and Jawzjan Integrated and Sustainabl...  ...  incoming
#
#    onBoundary                                      reportDetails  \
# 0      single  [{'sourceType': 'Primary', 'organization': 'It...
# 1      single  [{'sourceType': 'Primary', 'organization': 'Te...
# 2      single  [{'sourceType': 'Primary', 'organization': 'Te...
# 3      single  [{'sourceType': 'Primary', 'organization': 'Te...
# 4      single  [{'sourceType': 'Primary', 'organization': 'Te...
#
#          refCode SourceWord Organization Count  \
# 0  AID 9908/01/0        AFG                  1
# 1            NaN        AFG                  1
# 2            NaN        AFG                  1
# 3            NaN        AFG                  1
# 4            NaN        AFG                  1
#
#                               Organization Organization Type  \
# 0                     Italy, Government of       Governments
# 1            United Kingdom, Government of       Governments
# 2            United Kingdom, Government of       Governments
# 3  United States of America, Government of       Governments
# 4  United States of America, Government of       Governments
#
#   Organization Sub Type                      Organization Level
# 0  National Governments  National and Sub-National State Actors
# 1  National Governments  National and Sub-National State Actors
# 2  National Governments  National and Sub-National State Actors
# 3  National Governments  National and Sub-National State Actors
# 4  National Governments  National and Sub-National State Actors
#
# [5 rows x 35 columns]

# %%
aggregated_df[aggregated_df['id']==100131].head()
# Out:
#         Unnamed: 0        id  amountUSD  budgetYear childFlowIds  \
# 0              0.0  100131.0   621891.0      2013.0          NaN
# 145905         8.0  100131.0   621891.0      2013.0          NaN
#
#        contributionType             createdAt                  date  \
# 0             financial  2012-11-12T16:26:00Z  2012-07-10T00:00:00Z
# 145905        financial  2012-11-12T16:26:00Z  2012-07-10T00:00:00Z
#
#                 decisionDate  \
# 0       2012-07-10T00:00:00Z
# 145905  2012-07-10T00:00:00Z
#
#                                               description  ...  boundary  \
# 0       Multilateral contribution to UNMAS: Support to...  ...  incoming
# 145905  Multilateral contribution to UNMAS: Support to...  ...  outgoing
#
#         onBoundary                                      reportDetails  \
# 0           single  [{'sourceType': 'Primary', 'organization': 'It...
# 145905      single  [{'sourceType': 'Primary', 'organization': 'It...
#
#               refCode SourceWord Organization Count          Organization  \
# 0       AID 9908/01/0        AFG                  1  Italy, Government of
# 145905  AID 9908/01/0        ITA                  1  Italy, Government of
#
#        Organization Type Organization Sub Type  \
# 0            Governments  National Governments
# 145905       Governments  National Governments
#
#                             Organization Level
# 0       National and Sub-National State Actors
# 145905  National and Sub-National State Actors
#
# [2 rows x 35 columns]

# %%
final_df = aggregated_df[['id','Organization','SourceWord','description','boundary',
                          'Organization Type','Organization Sub Type','Organization Level',
                          'amountUSD','contributionType','method','date','status','Organization Count']]

# %%
final_df = final_df[final_df['boundary']=='incoming']
final_df.head()
# Out:
#          id                             Organization SourceWord  \
# 0  100131.0                     Italy, Government of        AFG
# 1  100144.0            United Kingdom, Government of        AFG
# 2  100145.0            United Kingdom, Government of        AFG
# 3  100146.0  United States of America, Government of        AFG
# 4  100147.0  United States of America, Government of        AFG
#
#                                          description  boundary  \
# 0  Multilateral contribution to UNMAS: Support to...  incoming
# 1  Emergency WASH support to schools in drought i...  incoming
# 2  Emergency Support to Drought and floods affect...  incoming
# 3  Kandahar and Jawzjan Integrated and Sustainabl...  incoming
# 4  Kandahar and Jawzjan Integrated and Sustainabl...  incoming
#
#   Organization Type Organization Sub Type  \
# 0       Governments  National Governments
# 1       Governments  National Governments
# 2       Governments  National Governments
# 3       Governments  National Governments
# 4       Governments  National Governments
#
#                        Organization Level  amountUSD contributionType  \
# 0  National and Sub-National State Actors   621891.0        financial
# 1  National and Sub-National State Actors    90928.0        financial
# 2  National and Sub-National State Actors    47680.0        financial
# 3  National and Sub-National State Actors  1358086.0        financial
# 4  National and Sub-National State Actors   117952.0        financial
#
#             method                  date      status  Organization Count
# 0  Traditional aid  2012-07-10T00:00:00Z  commitment                   1
# 1  Traditional aid  2012-05-01T00:00:00Z        paid                   1
# 2  Traditional aid  2012-05-01T00:00:00Z        paid                   1
# 3  Traditional aid  2012-09-01T00:00:00Z        paid                   1
# 4  Traditional aid  2012-09-01T00:00:00Z        paid                   1

# %%
final_df = final_df.rename(columns={"id": "flow_id", "SourceWord": "country_iso3"})
final_df.head()
# Out:
#     flow_id                             Organization country_iso3  \
# 0  100131.0                     Italy, Government of          AFG
# 1  100144.0            United Kingdom, Government of          AFG
# 2  100145.0            United Kingdom, Government of          AFG
# 3  100146.0  United States of America, Government of          AFG
# 4  100147.0  United States of America, Government of          AFG
#
#                                          description  boundary  \
# 0  Multilateral contribution to UNMAS: Support to...  incoming
# 1  Emergency WASH support to schools in drought i...  incoming
# 2  Emergency Support to Drought and floods affect...  incoming
# 3  Kandahar and Jawzjan Integrated and Sustainabl...  incoming
# 4  Kandahar and Jawzjan Integrated and Sustainabl...  incoming
#
#   Organization Type Organization Sub Type  \
# 0       Governments  National Governments
# 1       Governments  National Governments
# 2       Governments  National Governments
# 3       Governments  National Governments
# 4       Governments  National Governments
#
#                        Organization Level  amountUSD contributionType  \
# 0  National and Sub-National State Actors   621891.0        financial
# 1  National and Sub-National State Actors    90928.0        financial
# 2  National and Sub-National State Actors    47680.0        financial
# 3  National and Sub-National State Actors  1358086.0        financial
# 4  National and Sub-National State Actors   117952.0        financial
#
#             method                  date      status  Organization Count
# 0  Traditional aid  2012-07-10T00:00:00Z  commitment                   1
# 1  Traditional aid  2012-05-01T00:00:00Z        paid                   1
# 2  Traditional aid  2012-05-01T00:00:00Z        paid                   1
# 3  Traditional aid  2012-09-01T00:00:00Z        paid                   1
# 4  Traditional aid  2012-09-01T00:00:00Z        paid                   1

# %%
final_df.tail()
# Out:
#         flow_id                                       Organization  \
# 430870  99685.0            United States of America, Government of
# 430871  99686.0            United States of America, Government of
# 430872  99687.0            United States of America, Government of
# 430873  99793.0  European Commission's Humanitarian Aid and Civ...
# 430874  99938.0  European Commission's Humanitarian Aid and Civ...
#
#        country_iso3                                        description  \
# 430870          ZWE         Water, Sanitation and Hygiene (USAID/OFDA)
# 430871          ZWE  Water, Sanitation and Hygiene - through USAID ...
# 430872          ZWE  Natural And Technological Risks, Agriculture a...
# 430873          ZWE  Emergency WASH Response by Environmental Healt...
# 430874          ZWE  Environmental Health Alliance (ECHO/ZWE/BUD/20...
#
#         boundary           Organization Type  \
# 430870  incoming                 Governments
# 430871  incoming                 Governments
# 430872  incoming                 Governments
# 430873  incoming  Multilateral Organizations
# 430874  incoming  Multilateral Organizations
#
#                    Organization Sub Type  \
# 430870              National Governments
# 430871              National Governments
# 430872              National Governments
# 430873  Other Multilateral Organizations
# 430874  Other Multilateral Organizations
#
#                             Organization Level  amountUSD contributionType  \
# 430870  National and Sub-National State Actors   341540.0        financial
# 430871  National and Sub-National State Actors   498116.0        financial
# 430872  National and Sub-National State Actors  1553381.0        financial
# 430873                    International Actors  2600000.0        financial
# 430874                    International Actors  1287001.0        financial
#
#                  method                  date      status  Organization Count
# 430870  Traditional aid  2011-06-21T00:00:00Z  commitment                   1
# 430871  Traditional aid  2011-08-07T00:00:00Z  commitment                   1
# 430872  Traditional aid  2012-06-04T00:00:00Z  commitment                   1
# 430873  Traditional aid  2011-12-14T00:00:00Z  commitment                   1
# 430874  Traditional aid  2011-12-14T00:00:00Z  commitment                   1

# %%
final_df.to_excel(directory+'FTS_clean_data_latest.xlsx')
